# %%
from entsoe import EntsoePandasClient
import pandas as pd

import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent / 'scripts'))
from _tokens import ENTSOE_API_KEY

client = EntsoePandasClient(api_key=ENTSOE_API_KEY)

start = pd.Timestamp('20241223', tz='utc')
end = pd.Timestamp('20241226', tz='utc')

countries = [
    'IE_SEM',
    'DK_1',
    'FR',
    'NL',
    'BE',
]

data = []

for cc in countries:
    print(f'Querying {cc}...')
    series = client.query_day_ahead_prices(cc, start=start, end=end).rename(cc)

    data.append(series)
# Out:
# Querying IE_SEM...
# Querying DK_1...
# Querying FR...
# Querying NL...
# Querying BE...

# %%
pd.concat((data), axis=1).plot()
# Out:
# <Axes: >

# %%
help(client.query_day_ahead_prices)
# Out:
# Help on method query_day_ahead_prices in module entsoe.entsoe:
#
# query_day_ahead_prices(country_code: Union[entsoe.mappings.Area, str], start: pandas._libs.tslibs.timestamps.Timestamp, end: pandas._libs.tslibs.timestamps.Timestamp, resolution: Literal['60min', '30min', '15min'] = '60min') -> pandas.core.series.Series method of entsoe.entsoe.EntsoePandasClient instance
#     Parameters
#     ----------
#     resolution: either 60min for hourly values,
#         30min for half-hourly values or 15min for quarterly values, throws error if type is not available
#     country_code : Area|str
#     start : pd.Timestamp
#     end : pd.Timestamp
#
#     Returns
#     -------
#     pd.Series

# %%
p.plot()
# Out:
# <Axes: >
